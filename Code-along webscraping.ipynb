# %%
pip install selenium webdriver_manager pandas bs4 requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: selenium in c:\users\tipqc\appdata\roaming\python\python312\site-packages (4.40.0)
# Requirement already satisfied: webdriver_manager in c:\users\tipqc\appdata\roaming\python\python312\site-packages (4.0.2)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: bs4 in c:\users\tipqc\appdata\roaming\python\python312\site-packages (0.0.2)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (2.32.2)
# Requirement already satisfied: certifi>=2026.1.4 in c:\users\tipqc\appdata\roaming\python\python312\site-packages (from selenium) (2026.1.4)
# Requirement already satisfied: trio<1.0,>=0.31.0 in c:\users\tipqc\appdata\roaming\python\python312\site-packages (from selenium) (0.33.0)
# Requirement already satisfied: trio-websocket<1.0,>=0.12.2 in c:\users\tipqc\appdata\roaming\python\python312\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: trio-typing>=0.10.0 in c:\users\tipqc\appdata\roaming\python\python312\site-packages (from selenium) (0.10.0)
# Requirement already satisfied: types-certifi>=2021.10.8.3 in c:\users\tipqc\appdata\roaming\python\python312\site-packages (from selenium) (2021.10.8.3)
# Requirement already satisfied: types-urllib3>=1.26.25.14 in c:\users\tipqc\appdata\roaming\python\python312\site-packages (from selenium) (1.26.25.14)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in c:\users\tipqc\appdata\roaming\python\python312\site-packages (from selenium) (4.15.0)
# Requirement already satisfied: urllib3<3.0,>=2.6.3 in c:\users\tipqc\appdata\roaming\python\python312\site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (2.6.3)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in c:\programdata\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: python-dotenv in c:\programdata\anaconda3\lib\site-packages (from webdriver_manager) (0.21.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from webdriver_manager) (23.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\programdata\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\tipqc\appdata\roaming\python\python312\site-packages (from trio<1.0,>=0.31.0->selenium) (25.4.0)
# Requirement already satisfied: sortedcontainers in c:\programdata\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: outcome in c:\users\tipqc\appdata\roaming\python\python312\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\programdata\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\programdata\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.16.0)
# Requirement already satisfied: mypy-extensions>=0.4.2 in c:\programdata\anaconda3\lib\site-packages (from trio-typing>=0.10.0->selenium) (1.0.0)
# Requirement already satisfied: async-generator in c:\users\tipqc\appdata\roaming\python\python312\site-packages (from trio-typing>=0.10.0->selenium) (1.10)
# Requirement already satisfied: importlib-metadata in c:\programdata\anaconda3\lib\site-packages (from trio-typing>=0.10.0->selenium) (7.0.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\tipqc\appdata\roaming\python\python312\site-packages (from trio-websocket<1.0,>=0.12.2->selenium) (1.3.2)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\programdata\anaconda3\lib\site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (1.7.1)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.5)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.16.0 in c:\users\tipqc\appdata\roaming\python\python312\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata->trio-typing>=0.10.0->selenium) (3.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver 
from selenium.webdriver.firefox.service import Service 
from selenium.webdriver.firefox.options import Options 
from webdriver_manager.firefox import GeckoDriverManager
import time 
from bs4 import BeautifulSoup

#setup firefox
local_driver_path = "./geckodriver.exe"
firefox_binary_path = r"C:\program Files\Mozilla Firefox\firefox.exe"
options = Options()
options.binary_location = firefox_binary_path

#service = Service(GeckoDriverManager().install())
service = Service(executable_path=local_driver_path)
#driver = webdriver.Firefox(service=service)
driver = webdriver.Firefox(service=service, options=options)

html = driver.get("https://www.google.com")
print("Page Title: ", driver.title)
# Out:
# Page Title:  Google

# %%
url = "https://www.imdb.com/chart/top/"
driver.get(url)

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollheight);')
html = driver.page_source

# %%
soup = BeautifulSoup(html, 'html.parser')

data = soup.find

# %%
import pandas as pd 

data = {
    "titles":titles,
    "ratings":ratings,
    "votes":votes,

}

# %%
numbers = {
    "K":1_000,
    "M":1_000_000

}

def votes_to_float():
    unit = vote[-1]
    if unit in numbers:
        result = float(vote[:-1])
        result = result * numbers[unit]
    else:
        result = float(vote)
    return result


votes_to_float("10K")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 17
#      13         result = float(vote)
#      14     return result
# ---> 17 votes_to_float("10K")
#
# TypeError: votes_to_float() takes 0 positional arguments but 1 was given

# %%
df["votes"] = df["votes"].map(votes_to_float)

df

# %%
df.to_csv("module7_imdb.csv")
