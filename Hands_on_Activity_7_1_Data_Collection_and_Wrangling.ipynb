# %% [markdown]
# <a href="https://colab.research.google.com/github/valesed/GitHub-Repository-for-CPE311/blob/main/Hands_on_Activity_7_1_Data_Collection_and_Wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exercise 1**
# We want to look at data for the Facebook, Apple, Amazon, Netflix, and Google (FAANG) stocks, but we were given each as a separate CSV file. Combine them into a single file and store the dataframe of the FAANG data as faang for the rest of the exercises:
# 1.	Read each file in.
# 2.	Add a column to each dataframe, called ticker, indicating the ticker symbol it is for (Apple's is AAPL, for example). This is how you look up a stock. Each file's name is also the ticker symbol, so be sure to capitalize it.
# 3.	Append them together into a single dataframe.
# 4.	Save the result in a CSV file called faang.csv.

# %%
import pandas as pd
import numpy as np

# %%
aapl = pd.read_csv('aapl.csv')
amzn = pd.read_csv('amzn.csv')
fb = pd.read_csv('fb.csv')
goog = pd.read_csv('goog.csv')
nflx = pd.read_csv('nflx.csv')

# %%
aapl["ticker"] = "AAPL"
amzn["ticker"] = "AMZN"
fb["ticker"] = "FB"
goog["ticker"] = "GOOG"
nflx["ticker"] = "NFLX"

# %%
faang = pd.concat([aapl, amzn, fb, goog, nflx], ignore_index=True)

# %%
faang.to_csv("faang.csv", index=False)

# %% [markdown]
# # **Exercise 2**
# •	With faang, use type conversion to change the date column into a datetime and the volume column into integers. Then, sort by date and ticker.
# •	Find the seven rows with the highest value for volume.
# •	Right now, the data is somewhere between long and wide format. Use melt() to make it completely long format. Hint: date and ticker are our ID variables (they uniquely identify each row). We need to melt the rest so that we don't have separate columns for open, high, low, close, and volume.

# %%
faang["date"] = pd.to_datetime(faang["date"])
faang["volume"] = faang["volume"].astype(int)

faang = faang.sort_values(["date","ticker"])

# %%
faang.nlargest(7, "volume")
# Out:
#           date      open      high       low     close     volume ticker
# 644 2018-07-26  174.8900  180.1300  173.7500  176.2600  169803668     FB
# 555 2018-03-20  167.4700  170.2000  161.9500  168.1500  129851768     FB
# 559 2018-03-26  160.8200  161.1000  149.0200  160.0600  126116634     FB
# 556 2018-03-21  164.8000  173.4000  163.3000  169.3900  106598834     FB
# 182 2018-09-21  219.0727  219.6482  215.6097  215.9768   96246748   AAPL
# 245 2018-12-21  156.1901  157.4845  148.9909  150.0862   95744384   AAPL
# 212 2018-11-02  207.9295  211.9978  203.8414  205.8755   91328654   AAPL

# %%
faang_long = faang.melt(
    id_vars=["date","ticker"],
    value_vars=["open","high","low","close","volume"],
    var_name="variable",
    value_name="value"
)

faang_long.head()
# Out:
#         date ticker variable      value
# 0 2018-01-02   AAPL     open   166.9271
# 1 2018-01-02   AMZN     open  1172.0000
# 2 2018-01-02     FB     open   177.6800
# 3 2018-01-02   GOOG     open  1048.3400
# 4 2018-01-02   NFLX     open   196.1000

# %% [markdown]
# # **Exercise 3**
# •	Using web scraping, search for the list of the hospitals, their address and contact information. Save the list in a new csv file, hospitals.csv.
# •	Using the generated hospitals.csv, convert the csv file into pandas dataframe. Prepare the data using the necessary preprocessing techniques.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = "https://filipinodoctors.org/hospitals/"

response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

names = []
locations = []
phones = []

cards = soup.find_all("div", class_="listing-item")

for card in cards:

    name = card.find("h3")
    location = card.find("span", class_="listing-location")
    phone = card.find("span", class_="listing-phone")

    names.append(name.text.strip() if name else None)
    locations.append(location.text.strip() if location else None)
    phones.append(phone.text.strip() if phone else None)

# %%
hospitals = pd.DataFrame({
    "Name": names,
    "Address": addresses,
    "Contact": contacts
})

hospitals
# Out:
# Empty DataFrame
# Columns: [Name, Address, Contact]
# Index: []

# %%
hospitals.to_csv("hospitals.csv", index=False)

# %%
hospitals.drop_duplicates(inplace=True)

if not hospitals.empty:
    hospitals["Name"] = hospitals["Name"].str.strip()
    hospitals["Address"] = hospitals["Address"].str.strip()
else:
    print("DataFrame 'hospitals' is empty, skipping string operations on 'Name' and 'Address'.")
# Out:
# DataFrame 'hospitals' is empty, skipping string operations on 'Name' and 'Address'.

# %% [markdown]
# # **In this activity, the FAANG stock datasets were combined into a single dataset and prepared using different data wrangling techniques such as converting data types, sorting the data, and reshaping it into long format. These steps helped organize and structure the data for easier analysis. For the web scraping task, attempts were made to gather hospital information from the selected website and save it into a CSV file. However, I was unable to successfully implement the data scraper and could not figure out what was causing the issue. Despite this, the activity still demonstrated the process of preparing and transforming datasets using data preprocessing techniques.**
